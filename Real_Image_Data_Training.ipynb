# %% [markdown]
# <h1>Real Image Data Training</h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.set_style('darkgrid')

# %%
import os

# %%
data_dir = '/home/kennedymungai/Documents/Projects/Python/tensorflow_intro/cell_images'

# %%
os.listdir(data_dir)
# Out:
# ['test', 'train']

# %%
from matplotlib.image import imread

# %%
test_path = data_dir + '/test/'
training_path = data_dir + '/train/'

# %%
os.listdir(test_path)
# Out:
# ['uninfected', 'parasitized']

# %%
os.listdir(training_path)
# Out:
# ['uninfected', 'parasitized']

# %%
os.listdir(training_path+'parasitized')[0]
# Out:
# 'C174P135NThinF_IMG_20151127_135311_cell_207.png'

# %%
para_cell = training_path + 'parasitized/' + \
    'C174P135NThinF_IMG_20151127_135311_cell_207.png'

# %%
plt.imshow(imread(para_cell))

# %%
uninfected_cell = training_path + 'uninfected/'

# %%
os.listdir(uninfected_cell)[0]
# Out:
# 'C33P1thinF_IMG_20150619_114756a_cell_20.png'

# %%
plt.imshow(imread(uninfected_cell + 'C33P1thinF_IMG_20150619_114756a_cell_20.png'))

# %%
len(os.listdir(training_path+'parasitized'))
# Out:
# 12480

# %%
len(os.listdir(training_path+'uninfected'))
# Out:
# 12480

# %%
len(os.listdir(test_path+'uninfected'))
# Out:
# 1300

# %%
len(os.listdir(test_path+'parasitized'))
# Out:
# 1300

# %%
dim1 = []
dim2 = []

for image_filename in os.listdir(test_path+'uninfected'):
    img = imread(test_path+'uninfected/'+image_filename)
    d1, d2, colors = img.shape
    dim1.append(d1)
    dim2.append(d2)

# %%
dim1, dim2
# Out:
# ([109,
#   115,
#   142,
#   133,
#   148,
#   142,
#   142,
#   145,
#   115,
#   121,
#   166,
#   121,
#   148,
#   136,
#   136,
#   154,
#   115,
#   142,
#   121,
#   124,
#   136,
#   136,
#   124,
#   166,
#   154,
#   139,
#   127,
#   136,
#   124,
#   136,
#   136,
#   112,
#   109,
#   133,
#   106,
#   121,
#   112,
#   130,
#   136,
#   109,
#   121,
#   121,
#   121,
#   145,
#   124,
#   91,
#   130,
#   115,
#   121,
#   124,
#   112,
#   145,
#   124,
#   148,
#   154,
#   109,
#   127,
#   148,
#   130,
#   103,
#   118,
#   130,
#   148,
#   121,
#   106,
#   145,
#   130,
#   160,
#   130,
#   100,
#   121,
#   106,
#   130,
#   103,
#   130,
#   118,
#   130,
#   127,
#   124,
#   130,
#   127,
#   154,
#   121,
#   130,
#   106,
#   112,
#   139,
#   130,
#   133,
#   142,
#   154,
#   154,
#   127,
#   157,
#   112,
#   130,
#   118,
#   142,
#   112,
#   142,
#   169,
#   121,
#   154,
#   136,
#   121,
#   142,
#   115,
#   127,
#   124,
#   136,
#   106,
# ...

# %%
np.mean(dim1), np.mean(dim2)
# Out:
# (130.92538461538462, 130.75)

# %%
image_shape = (130, 130, 3)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_gen = ImageDataGenerator(rotation_range=20, width_shift_range=0.1, height_shift_range=0.1,
                               shear_range=0.1, zoom_range=0.1, horizontal_flip=True, fill_mode='nearest')

# %%
para_img = imread(para_cell)

# %%
plt.imshow(para_img)

# %%
plt.imshow(image_gen.random_transform(para_img))

# %%
image_gen.flow_from_directory(training_path)
# Out:
# Found 24958 images belonging to 2 classes.

# %%
image_gen.flow_from_directory(test_path)
# Out:
# Found 2600 images belonging to 2 classes.
